# %%
# %cd yolov7
# Out:
# c:\Schoolwork\CS585\Project\yolov7

# %%
# !pip install -r requirements.txt

# %% [markdown]
# Inference with given inference script

# %%
#Fine tuned model

# !python detect.py --weights C:/Schoolwork/CS585/Project/best.pt --source C:/Schoolwork/CS585/Project/video_candidates/phone_inference3.mp4 \
--save-txt
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.25, device='', exist_ok=False, img_size=640, iou_thres=0.45, name='exp', no_trace=False, nosave=False, project='runs/detect', save_conf=False, save_txt=True, source='C:/Schoolwork/CS585/Project/video_candidates/phone_inference3.mp4', update=False, view_img=False, weights=['C:/Schoolwork/CS585/Project/best.pt'])
# Fusing layers...
# IDetect.fuse
#  Convert model to Traced-model...
#  traced_script_module saved!
#  model is traced!
#
# video 1/1 (1/1827) C:\Schoolwork\CS585\Project\video_candidates\phone_inference3.mp4: 6 Cars, Done. (2.0ms) Inference, (47.2ms) NMS
# video 1/1 (2/1827) C:\Schoolwork\CS585\Project\video_candidates\phone_inference3.mp4: 7 Cars, Done. (4.0ms) Inference, (1.0ms) NMS
# video 1/1 (3/1827) C:\Schoolwork\CS585\Project\video_candidates\phone_inference3.mp4: 10 Cars, Done. (3.0ms) Inference, (1.0ms) NMS
# ...

# %%
#Original YOLOv7 model for comparison

# !python detect.py --weights C:/Schoolwork/CS585/Project/yolov7/yolov7-tiny.pt --source C:/Schoolwork/CS585/Project/dashcam_video/LOCA0440.mp4 \
--save-txt
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.25, device='', exist_ok=False, img_size=640, iou_thres=0.45, name='exp', no_trace=False, nosave=False, project='runs/detect', save_conf=False, save_txt=True, source='C:/Schoolwork/CS585/Project/dashcam_video/LOCA0440.mp4', update=False, view_img=False, weights=['C:/Schoolwork/CS585/Project/yolov7/yolov7-tiny.pt'])
# Fusing layers...
#  Convert model to Traced-model...
#  traced_script_module saved!
#  model is traced!
#
# video 1/1 (1/1799) C:\Schoolwork\CS585\Project\dashcam_video\LOCA0440.mp4: 9 cars, Done. (1.0ms) Inference, (62.2ms) NMS
# video 1/1 (2/1799) C:\Schoolwork\CS585\Project\dashcam_video\LOCA0440.mp4: 11 cars, Done. (2.0ms) Inference, (1.0ms) NMS
# video 1/1 (3/1799) C:\Schoolwork\CS585\Project\dashcam_video\LOCA0440.mp4: 7 cars, Done. (2.0ms) Inference, (0.0ms) NMS
# video 1/1 (4/1799) C:\Schoolwork\CS585\Project\dashcam_video\LOCA0440.mp4: 8 cars, Done. (2.0ms) Inference, (1.0ms) NMS
# ...

# %% [markdown]
# Modified Inference with Distance Measurement

# %%
#Distances Incorporated

# !python detect_update.py --weights C:/Schoolwork/CS585/Project/best.pt --source C:/Schoolwork/CS585/Project/video_candidates/phone_inference1.mp4 \
--save-txt
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.25, device='', exist_ok=False, img_size=640, iou_thres=0.45, name='exp', no_trace=False, nosave=False, project='runs/detect', save_conf=False, save_txt=True, source='C:/Schoolwork/CS585/Project/video_candidates/phone_inference1.mp4', update=False, view_img=False, weights=['C:/Schoolwork/CS585/Project/best.pt'])
# Fusing layers...
# IDetect.fuse
#  Convert model to Traced-model...
#  traced_script_module saved!
#  model is traced!
#
# video 1/1 (1/1822) C:\Schoolwork\CS585\Project\video_candidates\phone_inference1.mp4: 6 Cars, 1 Van, Done. (2.0ms) Inference, (40.8ms) NMS
# video 1/1 (2/1822) C:\Schoolwork\CS585\Project\video_candidates\phone_inference1.mp4: 6 Cars, 1 Van, Done. (3.0ms) Inference, (1.0ms) NMS
# video 1/1 (3/1822) C:\Schoolwork\CS585\Project\video_candidates\phone_inference1.mp4: 7 Cars, 1 Van, Done. (3.0ms) Inference, (0.0ms) NMS
# ...

# %%
#Distances Incorporated

# !python detect_update.py --weights C:/Schoolwork/CS585/Project/yolov7/yolov7-tiny.pt --source C:/Schoolwork/CS585/Project/video_candidates/phone_inference1.mp4 \
--save-txt
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.25, device='', exist_ok=False, img_size=640, iou_thres=0.45, name='exp', no_trace=False, nosave=False, project='runs/detect', save_conf=False, save_txt=True, source='C:/Schoolwork/CS585/Project/video_candidates/phone_inference1.mp4', update=False, view_img=False, weights=['C:/Schoolwork/CS585/Project/yolov7/yolov7-tiny.pt'])
# Fusing layers...
#  Convert model to Traced-model...
#  traced_script_module saved!
#  model is traced!
#
# video 1/1 (1/1822) C:\Schoolwork\CS585\Project\video_candidates\phone_inference1.mp4: 10 cars, 1 truck, 2 traffic lights, Done. (2.0ms) Inference, (48.2ms) NMS
# video 1/1 (2/1822) C:\Schoolwork\CS585\Project\video_candidates\phone_inference1.mp4: 11 cars, 2 traffic lights, Done. (3.0ms) Inference, (1.0ms) NMS
# video 1/1 (3/1822) C:\Schoolwork\CS585\Project\video_candidates\phone_inference1.mp4: 11 cars, 2 traffic lights, 1 bottle, Done. (3.0ms) Inference, (1.0ms) NMS
# ...
